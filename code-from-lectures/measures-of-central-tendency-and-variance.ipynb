# %%
import statistics
 
# Enter the data
data = [10, 12, 15, 15, 18, 20, 22, 25]
# Measures of Central Tendency
mean = statistics.mean(data)
median = statistics.median(data)
mode = statistics.mode(data)
# Measures of Dispersion
variance = statistics.pvariance(data)    
std_dev = statistics.pstdev(data)          
# Display results
print("Mean =", mean)
print("Median =", median)
print("Mode =", mode)
print("Variance =", variance)
print("Standard Deviation =", std_dev)
# Out:
# Mean = 17.125
# Median = 16.5
# Mode = 15
# Variance = 22.609375
# Standard Deviation = 4.7549316504025585
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 19
#      15 print("Mode =", mode)
#      16 print("Variance =", variance)
#      17 print("Standard Deviation =", std_dev)
#      18
# ---> 19 print(data.describe().tostring())
#
# AttributeError: 'list' object has no attribute 'describe'
